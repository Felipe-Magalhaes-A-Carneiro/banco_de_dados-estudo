# %% [markdown]
# # ***Criação de Tabelas - SQLite***

# %% [markdown]
# Tutorial: https://docs.python.org/3/library/sqlite3.html

# %% [markdown]
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # ***1. Como fazer?***

# %% [markdown]
# ## ***1.1. Código usado***

# %% [markdown]
# ----------------------------------------------------------------------------------------------------
